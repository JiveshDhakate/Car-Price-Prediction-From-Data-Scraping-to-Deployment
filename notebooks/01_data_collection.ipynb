# %% [markdown]
# # **Data Collection**
# ***Data Source - BlueMotive Cars***

# %%
import urllib.request
import pandas as pd
from bs4 import BeautifulSoup
import bs4
import os
import re

# %% [markdown]
# ## **`fetch_cars_details(url)`**
#
# The function **fetches HTML content** from a given webpage using `urllib.request`. It plays a crucial role in web scraping by retrieving the page’s source code for further processing.
#
# ---
#
# **Functionality:**
#
# - **Sends an HTTP request** to fetch webpage content.
# - **Retrieves and decodes HTML** into a readable format.
# - **Returns the HTML** for further data extraction.
# - **Handles errors gracefully** (e.g., invalid URL, server issues).
#
# ---

# %%
def fetch_cars_details(url):
    try:
        response = urllib.request.urlopen(url)
        html = response.read().decode()
        return html
    except urllib.error.URLError as e:
        print(f'Fetching Failed from {url}. Error: {e}')
        return None

# %% [markdown]
# ## **extract_total_pages(html_content)**
#
# The function extracts the **total number of pages** from the given HTML content. It helps in paginating through multiple pages in web scraping.
#
# **Functionality:**
# - **Parses the HTML** using `BeautifulSoup`.
# - **Finds the `<h2>` tag**, which contains the total page count.
# - **Uses regex** to extract the last page number.
# - **Returns the total pages** as an integer.
# - **Defaults to 1** if no page information is found.

# %%
def extract_total_pages(html_content):
    soup = BeautifulSoup(html_content, "html.parser")
    page_info = soup.find("h2")

    if page_info:
        match = re.search(r'Page \d+ of (\d+)', page_info.text)
        if match:
            return int(match.group(1))
    return 1

# %% [markdown]
# ## **extract_car_details(html_content)**
#
# The function extracts **car details** from the given HTML content, parsing structured data such as **brand, model, price, year, and specifications**.
#
# **Functionality:**
# - **Checks if HTML content exists**, otherwise returns an empty list.
# - **Parses the HTML** using `BeautifulSoup` to extract structured information.
# - **Extracts the brand name** from the `<title>` tag.
# - **Finds all car listings (`<li>` elements)** and processes them.
# - **Extracts model names** from `<span class="make-model">`.
# - **Retrieves car attributes** (e.g., price, year, mileage) from `<table class="car">`.
# - **Stores all extracted details** in a list of dictionaries.
# - **Returns the final list of car details** for further processing.

# %%
def extract_car_details(html_content):
    if not html_content:
        print("No HTML content to process.")
        return []

    soup = BeautifulSoup(html_content, "html.parser")

    title = soup.find("title").text.strip()
    brand_name = title.split("-")[-1].strip()

    car_details = []

    for li in soup.find_all("li"):
        model_tag = li.find("span", class_="make-model")
        car_data = {}

        if model_tag:
            car_data["Model"] = model_tag.text.strip()
            car_data["Brand"] = brand_name

            table = li.find("table", class_="car")
            if table:
                for row in table.find_all("tr"):
                    cells = row.find_all("td")
                    if len(cells) == 2:
                        key = cells[0].text.replace(":", "").strip()
                        value = cells[1].text.strip()
                        car_data[key] = value

            car_details.append(car_data)
    return car_details

# %% [markdown]
# ## **fetch_all_pages(base_url)**
#
# The function **fetches and extracts car details** from multiple pages dynamically by detecting the total number of pages and iterating through them.
#
# **Functionality:**
# - **Formats the first page URL** to initiate data extraction.
# - **Fetches the first page's HTML content** to determine the total number of pages.
# - **Extracts the total pages** using `extract_total_pages()`.
# - **Loops through all detected pages**, dynamically formatting the URL.
# - **Fetches HTML content for each page** using `fetch_cars_details()`.
# - **Extracts car details** from each page using `extract_car_details()`.
# - **Combines all extracted car data** into a single list.
# - **Returns the final dataset** containing car listings from all pages.

# %%
def fetch_all_pages(base_url):
    first_page_url = base_url.format(1)
    first_page_html = fetch_cars_details(first_page_url)

    if not first_page_html:
        print("Failed to fetch the first page. Exiting.")
        return []

    total_pages = extract_total_pages(first_page_html)
    print(f"Total pages detected: {total_pages}")

    all_cars = []
    for page_num in range(1, total_pages + 1):
        url = base_url.format(page_num)
        print(f"Fetching: {url}")

        html_data = fetch_cars_details(url)
        if html_data:
            all_cars.extend(extract_car_details(html_data))
    print(all_cars)
    return all_cars

# %% [markdown]
# ## **save_to_csv(car_data, brand_name, output_folder)**
#
# The function **saves extracted car data** into a CSV file, ensuring structured storage for further analysis.
#
# **Functionality:**
# - **Creates a pandas DataFrame** from the extracted car details.
# - **Formats the CSV filename** using the brand name (e.g., `Audi.csv`).
# - **Constructs the file path** using the specified output folder.
# - **Saves the DataFrame as a CSV file** without the index column.
# - **Prints a confirmation message** upon successful saving.
# - **Returns the file path** of the saved CSV file.

# %%
def save_to_csv(car_data, brand_name, output_folder="/Users/jiveshdhakate/Documents/UCD Sem 2/Data Science in Python/car_price_predictor/data"):
    if not car_data:
        print("No data to save.")
        return None

    df = pd.DataFrame(car_data)
    csv_filename = f"{brand_name}.csv"
    csv_path = os.path.join(output_folder, csv_filename)
    df.to_csv(csv_path, index=False)

    print(f"{brand_name} Car Data saved to {csv_path}")
    return csv_path

# %%
urls = [
    "http://mlg.ucd.ie/modules/python/assignment1/cars/Audi-page{:02d}.html",
    "http://mlg.ucd.ie/modules/python/assignment1/cars/BMW-page{:02d}.html",
    "http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page{:02d}.html",
    "http://mlg.ucd.ie/modules/python/assignment1/cars/Volkswagen-page{:02d}.html"
]

for url in urls:
    car_data = fetch_all_pages(url)

    if car_data:
        brand_name = car_data[0].get("Brand", "Unknown")
        save_to_csv(car_data, brand_name)
# Out:
# Total pages detected: 20
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Audi-page01.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Audi-page02.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Audi-page03.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Audi-page04.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Audi-page05.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Audi-page06.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Audi-page07.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Audi-page08.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Audi-page09.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Audi-page10.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Audi-page11.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Audi-page12.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Audi-page13.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Audi-page14.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Audi-page15.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Audi-page16.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Audi-page17.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Audi-page18.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Audi-page19.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Audi-page20.html
# [{'Model': 'Audi A1 (TFSI)', 'Brand': 'Audi', 'Date of Sale': '06/01/2024', 'Sale Price': '€4,800.00', 'Year': '2012', 'Mileage': '130,377', 'Classification': 'Hatchback', 'Transmission': 'Manual', 'Fuel Type': 'Petrol', 'Description': 'Grey Audi A11.4 TFSI Sport Euro 5 (s/s) 3dr2 previous owners', 'Sale Location': 'Waterford'}, {'Model': 'Audi Q7 (S line Plus)', 'Brand': 'Audi', 'Date of Sale': '07/01/2024', 'Sale Price': '€14,450.00', 'Year': '2012', 'Mileage': '91,483', 'Classification': 'SUV', 'Transmission': 'Automatic', 'Fuel Type': 'Diesel', 'Description': 'Blue Audi Q73.0 TDI S line Plus Tiptronic quattro 5dr1 previous owner', 'Sale Location': 'Clare'}, {'Model': 'Audi RS3 (TFSI)', 'Brand': 'Audi', 'Date of Sale': '09/01/2024', 'Sale Price': '€70,256.00', 'Year': '2022', 'Mileage': '3,869', 'Classification': 'Saloon', 'Transmission': 'Automatic', 'Fuel Type': 'Petrol', 'Description': 'Black Audi RS3 SALOON2.5 RS 3 TFSI QUATTRO VORSPRUNG 4d 395 BHP TOP SPEC+S/S SEATS+MATRIX LED2 previous owners', 'Sale Location': 'Mayo'}, {'Model': 'Audi A3 (S line)', 'Brand': 'Audi', 'Date of Sale': '09/01/2024', 'Sale Price': '€10,308.00', 'Year': '2013', 'Mileage': '83,389', 'Classification': 'Hatchback', 'Transmission': 'Manual', 'Fuel Type': 'Diesel', 'Description': 'Black Audi A32.0 TDI S line Hatchback 3dr Diesel Manual Euro 5 (s/s) (150 ps)4 previous owners', 'Sale Location': 'Limerick'}, {'Model': 'Audi A6 Saloon (ultra)', 'Brand': 'Audi', 'Date of Sale': '2024-01-09', 'Sale Price': '€21,833.00', 'Year': '2018', 'Mileage': '42,918', 'Classification': 'Saloon', 'Transmission': 'Automatic', 'Fuel Type': 'Diesel', 'Description': 'Red Audi A6 Saloon2.0 TDI Ultra Black Edition 4dr S Tronic Leather Seats', 'Sale Location': 'Dublin'}, {'Model': 'Audi S3 (TFSI)', 'Brand': 'Audi', 'Date of Sale': '2024-01-09', 'Sale Price': '€20,345.00', 'Year': '2016', 'Mileage': '73451', 'Classification': 'Hatchback', 'Transmission': 'Automatic', 'Fuel Type': 'Petrol', 'Description': 'Blue Audi S32.0 TFSI Sportback 5dr Petrol S Tronic quattro Euro 6 (s/s) (310 ps)4 previous owners', 'Sale Location': 'Laois'}, {'Model': 'Audi Q2 (TFSI)', 'Brand': 'Audi', 'Date of Sale': '10/01/2024', 'Sale Price': '€27,307.00', 'Year': '2020', 'Mileage': '17,520', 'Classification': 'SUV', 'Transmission': 'Automatic', 'Fuel Type': 'Petrol', 'Description': 'Audi Q2S line 35 TFSI 150 PS S tronic 1.5 5dr', 'Sale Location': 'Dublin'}, {'Model': 'Audi Q2 (CoD)', 'Brand': 'Audi', 'Date of Sale': '10/01/2024', 'Sale Price': '€19,056.00', 'Year': '2018', 'Mileage': '60,224', 'Classification': 'SUV', 'Transmission': 'Automatic', 'Fuel Type': 'Petrol', 'Description': 'Blue Audi Q21.4 TFSI CoD S line S Tronic Euro 6 (s/s) 5dr1 previous owner', 'Sale Location': 'Donegal'}, {'Model': 'Audi TT (TFSI)', 'Brand': 'Audi', 'Date of Sale': '10/01/2024', 'Sale Price': '€ 7,166', 'Year': '2009', 'Mileage': '55,056', 'Classification': 'Convertible', 'Transmission': 'Manual', 'Fuel Type': 'Petrol', 'Description': 'Red Audi TT2.0 TFSI Roadster 2dr Petrol Manual Euro 4 (200 ps)3 previous owners', 'Sale Location': 'Dublin'}, {'Model': 'Audi Q2 (TFSI)', 'Brand': 'Audi', 'Date of Sale': '10/01/2024', 'Sale Price': '€21,153.00', 'Year': '2018', 'Mileage': '32,692', 'Classification': 'SUV', 'Transmission': 'Manual', 'Fuel Type': 'Petrol', 'Description': 'Navy Audi Q2S line 1.4 TFSI cylinder on demand 150 PS 6-speed 5dr2 previous owners', 'Sale Location': 'Cork'}, {'Model': 'Audi Q2 (CoD)', 'Brand': 'Audi', 'Date of Sale': '14/01/2024', 'Sale Price': '€29,341.00', 'Year': '2021', 'Mileage': '10,255', 'Classification': 'SUV', 'Transmission': 'Automatic', 'Fuel Type': 'Petrol', 'Description': 'Grey Audi Q2S line 35 TFSI 150 PS S tronic 1.5 5dr1 previous owner', 'Sale Location': 'Dublin'}, {'Model': 'Audi A1 (Black Edition)', 'Brand': 'Audi', 'Date of Sale': '2024-01-15', 'Sale Price': '€14,933.00', 'Year': '2016', 'Mileage': '31,341', 'Classification': 'Hatchback', 'Transmission': 'Automatic', 'Fuel Ty ...
# Audi Car Data saved to /Users/jiveshdhakate/Documents/UCD Sem 2/Data Science in Python/car_price_predictor/data/Audi.csv
# Total pages detected: 20
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/BMW-page01.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/BMW-page02.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/BMW-page03.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/BMW-page04.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/BMW-page05.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/BMW-page06.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/BMW-page07.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/BMW-page08.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/BMW-page09.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/BMW-page10.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/BMW-page11.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/BMW-page12.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/BMW-page13.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/BMW-page14.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/BMW-page15.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/BMW-page16.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/BMW-page17.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/BMW-page18.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/BMW-page19.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/BMW-page20.html
# [{'Model': 'BMW 4 Series (M Sport)', 'Brand': 'BMW', 'Date of Sale': '2024-01-02', 'Sale Price': '€15,899.00', 'Year': '2016', 'Mileage': '75,663', 'Classification': 'Convertible', 'Transmission': 'Automatic', 'Fuel Type': 'Diesel', 'Description': 'Blue BMW 4 SERIES420d 2.0 190 Bhp M SPORT NAV 2dr', 'Sale Location': 'Galway'}, {'Model': 'BMW 4 Series Gran Coupe (428i)', 'Brand': 'BMW', 'Date of Sale': '04/01/2024', 'Sale Price': '€20,641.00', 'Year': '2015', 'Mileage': '37,197', 'Classification': 'Hatchback', 'Transmission': 'Automatic', 'Fuel Type': 'Petrol', 'Description': 'Red BMW 4 Series Gran Coupe2.0 428i M Sport Auto Euro 6 (s/s) 5dr2 previous owners', 'Sale Location': 'Cork'}, {'Model': 'BMW 1 Series (116i)', 'Brand': 'BMW', 'Date of Sale': '04/01/2024', 'Sale Price': '€9,453.00', 'Year': '2012', 'Mileage': '43,305', 'Classification': 'Hatchback', 'Transmission': 'Manual', 'Fuel Type': 'Petrol', 'Description': 'Red BMW 1 SERIES1.6 116I SE 5d 135 BHP BLUETOOTH TELEPHONE CONNECTION2 previous owners', 'Sale Location': 'Dublin'}, {'Model': 'BMW 4 Series Gran Coupe (M Sport)', 'Brand': 'BMW', 'Date of Sale': '05/01/2024', 'Sale Price': '€18,819.00', 'Year': '2016', 'Mileage': '83,413', 'Classification': 'Hatchback', 'Transmission': 'Automatic', 'Fuel Type': 'Diesel', 'Description': 'Grey BMW 4 Series Gran Coupe3.0 435d M Sport Auto xDrive Euro 6 (s/s) 5dr3 previous owners', 'Sale Location': 'Cork'}, {'Model': 'BMW X2 (18d)', 'Brand': 'BMW', 'Date of Sale': '07/01/2024', 'Sale Price': '€19,818.00', 'Year': '2019', 'Mileage': '28,819', 'Classification': 'SUV', 'Transmission': 'Manual', 'Fuel Type': 'Diesel', 'Description': 'Red BMW X2xDrive 18d SE 5dr 2.01 previous owner', 'Sale Location': 'Laois'}, {'Model': 'BMW 3 Series (SE)', 'Brand': 'BMW', 'Date of Sale': '08/01/2024', 'Sale Price': '€14,244.00', 'Year': '2017', 'Mileage': '35,373 miles', 'Classification': 'Saloon', 'Transmission': 'Manual', 'Fuel Type': 'Diesel', 'Description': 'Blue BMW 3 SeriesBMW 3 316d 2.0 SE 4dr1 previous owner', 'Sale Location': 'Sligo'}, {'Model': 'BMW 1 Series (M Sport Shadow Edition)', 'Brand': 'BMW', 'Date of Sale': '2024-01-08', 'Sale Price': '€16,561.00', 'Year': '2018', 'Mileage': '38738', 'Classification': 'Hatchback', 'Transmission': 'Manual', 'Fuel Type': 'Petrol', 'Description': 'Black BMW 1 SERIES1.5 118I M SPORT SHADOW EDITION 5d 134 BHP1 previous owner', 'Sale Location': 'Dublin'}, {'Model': 'BMW X2 (Sport)', 'Brand': 'BMW', 'Date of Sale': '08/01/2024', 'Sale Price': '€30,481.00', 'Year': '2021', 'Mileage': '6,740', 'Classification': 'SUV', 'Transmission': 'Automatic', 'Fuel Type': 'Petrol', 'Description': 'Silver BMW X2 SeriesX2 sDrive20i Sport 2.0 5dr2 previous owners', 'Sale Location': 'Cavan'}, {'Model': 'BMW 4 Series Gran Coupe (Sport)', 'Brand': 'BMW', 'Date of Sale': '2024-01-10', 'Sale Price': '€12,713.00', 'Year': '2015', 'Mileage': '101,242', 'Classification': 'Hatchback', 'Transmission': 'Automatic', 'Fuel Type': 'Diesel', 'Description': 'Black BMW 4 Series Gran Coupe2.0 420d Sport Auto Euro 6 (s/s) 5dr2 previous owners', 'Sale Location': 'Dublin'}, {'Model': 'BMW 1 Series (118i)', 'Brand': 'BMW', 'Date of Sale': '10/01/2024', 'Sale Price': '€8,217.00', 'Year': '2015', 'Mileage': '131,119', 'Classification': 'Hatchback', 'Transmission': 'Manual', 'Fuel Type': 'Petrol', 'Description': 'Silver BMW 1 Series1.5 118i SE Euro 6 (s/s) 5dr2 previous owners', 'Sale Location': 'Galway'}, {'Model': 'BMW 5 Series (540i)', 'Brand': 'BMW', 'Date of Sale': '10/01/2024', 'Sale Price': '€23,374.00', 'Year': '2018', 'Mileage': '77,418', 'Classification': 'Saloon', 'Transmission': 'Automatic', 'Fuel Type': 'Petrol', 'Description': 'BMW 5 Series3.0 540i SE Auto xDrive Euro 6 (s/s) 4dr1 previous owner', 'Sale Location': 'Laois'}, {'Model': 'BMW 1 Series (Sport)', 'Brand': 'BMW', 'Date of Sale': '12/01/2024', 'Sale Price': '€2,758.00', 'Year': '2010', 'Mileage': '144154', 'Classification': 'Hatchback', 'Transmission': 'Manual', 'Fuel Type': ' ...
# BMW Car Data saved to /Users/jiveshdhakate/Documents/UCD Sem 2/Data Science in Python/car_price_predictor/data/BMW.csv
# Total pages detected: 30
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page01.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page02.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page03.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page04.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page05.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page06.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page07.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page08.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page09.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page10.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page11.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page12.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page13.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page14.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page15.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page16.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page17.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page18.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page19.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page20.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page21.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page22.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page23.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page24.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page25.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page26.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page27.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page28.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page29.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Mercedes-Benz-page30.html
# [{'Model': 'Mercedes-Benz GLA Class (GLA180)', 'Brand': 'Benz', 'Date of Sale': '02/01/2024', 'Sale Price': '€28,158.00', 'Year': '2019', 'Mileage': '10,107', 'Classification': 'SUV', 'Transmission': 'Automatic', 'Fuel Type': 'Petrol', 'Description': 'Red Mercedes-Benz GLAGla 180 Amg Line Edition 5Dr Auto 1.61 previous owner', 'Sale Location': 'Mayo'}, {'Model': 'Mercedes-Benz C Class (BlueEfficiency)', 'Brand': 'Benz', 'Date of Sale': '02/01/2024', 'Sale Price': '€ 7,480', 'Year': '2011', 'Mileage': '96,427', 'Classification': 'Saloon', 'Transmission': 'Automatic', 'Fuel Type': 'Diesel', 'Description': 'Red Mercedes-Benz C Class2.1 C220 CDI BlueEfficiency Sport Edition 125 7G-Tronic 4dr', 'Sale Location': 'Wicklow'}, {'Model': 'Mercedes-Benz C Class (C180)', 'Brand': 'Benz', 'Date of Sale': '03/01/2024', 'Sale Price': '€7,787.00', 'Year': '2012', 'Mileage': '97,058 miles', 'Classification': 'Saloon', 'Transmission': 'Automatic', 'Fuel Type': 'Petrol', 'Description': 'Blue Mercedes-Benz C Class1.6 C180 BlueEfficiency Executive SE G-Tronic+ Euro 5 (s/s) 4dr', 'Sale Location': 'Dublin'}, {'Model': 'Mercedes-Benz GLA Class (Urban Edition)', 'Brand': 'Benz', 'Date of Sale': '2024-01-05', 'Sale Price': '€24,399.00', 'Year': '2019', 'Mileage': '9,764 miles', 'Classification': 'SUV', 'Transmission': 'Automatic', 'Fuel Type': 'Petrol', 'Description': 'Silver Mercedes-Benz Gla Class1.6 GLA180 Urban Edition 7G-DCT Euro 6 (s/s) 5dr2 previous owners', 'Sale Location': 'Cork'}, {'Model': 'Mercedes-Benz C Class (Executive SE)', 'Brand': 'Benz', 'Date of Sale': '05/01/2024', 'Sale Price': '€ 10,694', 'Year': '2012', 'Mileage': '36,210', 'Classification': 'Saloon', 'Transmission': 'Automatic', 'Fuel Type': 'Petrol', 'Description': 'Silver Mercedes-Benz C Class1.6 C180 BlueEfficiency Executive SE G-Tronic+ Euro 5 (s/s) 4dr2 previous owners', 'Sale Location': 'Dublin'}, {'Model': 'Mercedes-Benz A Class (AMG Line)', 'Brand': 'Benz', 'Date of Sale': '2024-01-06', 'Sale Price': '€17,579.00', 'Year': '2017', 'Mileage': '36,092 miles', 'Classification': 'Hatchback', 'Transmission': 'Automatic', 'Fuel Type': 'Diesel', 'Description': 'Mercedes-Benz A Class1.5 A180d AMG Line 7G-DCT Euro 6 (s/s) 5dr2 previous owners', 'Sale Location': 'Cork'}, {'Model': 'Mercedes-Benz GLE Class (GLE300d)', 'Brand': 'Benz', 'Date of Sale': '06/01/2024', 'Sale Price': '€59,205.00', 'Year': '2020', 'Mileage': '9,394', 'Classification': 'SUV', 'Transmission': 'Automatic', 'Fuel Type': 'Diesel', 'Description': 'Blue Mercedes-Benz Gle Diesel EstateGLE 300d 4Matic AMG Line Prem Plus 5dr 9G-Tronic 2.01 previous owner', 'Sale Location': 'Kilkenny'}, {'Model': 'Mercedes-Benz E Class (SE)', 'Brand': 'Benz', 'Date of Sale': '07/01/2024', 'Sale Price': '€14,372.00', 'Year': '2013', 'Mileage': '36,156', 'Classification': 'Saloon', 'Transmission': 'Automatic', 'Fuel Type': 'Diesel', 'Description': 'Mercedes-Benz E Class2.1 E220 CDI SE 4DR AUTOMATIC2 previous owners', 'Sale Location': 'Kerry'}, {'Model': 'Mercedes-Benz E Class (AMG Line)', 'Brand': 'Benz', 'Date of Sale': '07/01/2024', 'Sale Price': '€24,196.00', 'Year': '2017', 'Mileage': '35149', 'Classification': 'Saloon', 'Transmission': 'Automatic', 'Fuel Type': 'Diesel', 'Description': 'Red Mercedes-Benz E Class Diesel SaloonE220d AMG Line 4dr 9G-Tronic 2.01 previous owner', 'Sale Location': 'Dublin'}, {'Model': 'Mercedes-Benz E Class (MHEV)', 'Brand': 'Benz', 'Date of Sale': '07/01/2024', 'Sale Price': '€65,120.00', 'Year': '2022', 'Mileage': '5,291', 'Classification': 'Saloon', 'Transmission': 'Automatic', 'Fuel Type': 'Petrol Hybrid', 'Description': 'Navy Mercedes-Benz E-ClassE53 4Matic+ Night Edition Prem+ 4dr TCT Petrol Saloon 3.0', 'Sale Location': 'Dublin'}, {'Model': 'Mercedes-Benz E Class (SE)', 'Brand': 'Benz', 'Date of Sale': '2024-01-09', 'Sale Price': '€8,645.00', 'Year': '2013', 'Mileage': '105,776', 'Classification': 'Estate', 'Transmission': 'Manual', 'Fuel Type': 'Diesel', 'Description': 'Black Mercedes-Benz E Cl ...
# Benz Car Data saved to /Users/jiveshdhakate/Documents/UCD Sem 2/Data Science in Python/car_price_predictor/data/Benz.csv
# Total pages detected: 17
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Volkswagen-page01.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Volkswagen-page02.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Volkswagen-page03.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Volkswagen-page04.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Volkswagen-page05.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Volkswagen-page06.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Volkswagen-page07.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Volkswagen-page08.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Volkswagen-page09.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Volkswagen-page10.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Volkswagen-page11.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Volkswagen-page12.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Volkswagen-page13.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Volkswagen-page14.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Volkswagen-page15.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Volkswagen-page16.html
# Fetching: http://mlg.ucd.ie/modules/python/assignment1/cars/Volkswagen-page17.html
# [{'Model': 'Volkswagen Golf (GTI)', 'Brand': 'Volkswagen', 'Date of Sale': '2024-01-02', 'Sale Price': '€8,193.00', 'Year': '2010', 'Mileage': '109,038', 'Classification': 'Hatchback', 'Transmission': 'Automatic', 'Fuel Type': 'Petrol', 'Description': 'Navy Volkswagen Golf2.0 TSI GTI DSG Euro 5 5dr6 previous owners', 'Sale Location': 'Dublin'}, {'Model': 'Volkswagen Polo (Match)', 'Brand': 'Volkswagen', 'Date of Sale': '02/01/2024', 'Sale Price': '€15,317.00', 'Year': '2020', 'Mileage': '23,397 miles', 'Classification': 'Hatchback', 'Transmission': 'Manual', 'Fuel Type': 'Petrol', 'Description': 'Navy Volkswagen Polo1.0 TSI 95 MATCH 5d 94 BHP \\xa31,755 Upgraded Extras, 6.5in Touchscreen Display, Apple CarPlay, Android Auto, MirrorLink, DAB / Bluetooth / USB, Front /1 previous owner', 'Sale Location': 'Dublin'}, {'Model': 'Volkswagen Golf (SE)', 'Brand': 'Volkswagen', 'Date of Sale': '03/01/2024', 'Sale Price': '€9,193.00', 'Year': '2014', 'Mileage': '62,329', 'Classification': 'Hatchback', 'Transmission': 'Manual', 'Fuel Type': 'Diesel', 'Description': 'Black Volkswagen GolfSE TDI BLUEMOTION TECHNOLOGY 1.6 5dr3 previous owners', 'Sale Location': 'Wexford'}, {'Model': 'Volkswagen Tiguan (TDI)', 'Brand': 'Volkswagen', 'Date of Sale': '05/01/2024', 'Sale Price': '€9,849.00', 'Year': '2015', 'Mileage': '79,695', 'Classification': 'SUV', 'Transmission': 'Manual', 'Fuel Type': 'Diesel', 'Description': 'Blue Volkswagen Tiguan2.0 TDI BlueMotion Tech Match 4WD Euro 5 (s/s) 5dr', 'Sale Location': 'Longford'}, {'Model': 'Volkswagen Passat (Highline)', 'Brand': 'Volkswagen', 'Date of Sale': '06/01/2024', 'Sale Price': '€3,086.00', 'Year': '2009', 'Mileage': '105,044', 'Classification': 'Saloon', 'Transmission': 'Manual', 'Fuel Type': 'Diesel', 'Description': 'Volkswagen Passat2.0 TDI Highline Euro 5 4dr3 previous owners', 'Sale Location': 'Cork'}, {'Model': 'Volkswagen Scirocco (R-Line)', 'Brand': 'Volkswagen', 'Date of Sale': '07/01/2024', 'Sale Price': '€16,381.00', 'Year': '2017', 'Mileage': '46,777', 'Classification': 'Hatchback', 'Transmission': 'Automatic', 'Fuel Type': 'Diesel', 'Description': 'Navy Volkswagen Scirocco2.0 R LINE TDI BLUEMOTION TECHNOLOGY DSG 2d 148 BHP **F/S/H**\\xa320 ROAD TAX**19"ALLOYS**2 previous owners', 'Sale Location': 'Dublin'}, {'Model': 'Volkswagen T-Cross (TSI EVO)', 'Brand': 'Volkswagen', 'Date of Sale': '07/01/2024', 'Sale Price': '€27,176.00', 'Year': '2020', 'Mileage': '6,902', 'Classification': 'SUV', 'Transmission': 'Automatic', 'Fuel Type': 'Petrol', 'Description': 'Blue Volkswagen T-Cross1.5 TSI (150ps) R-Line EVO DSG 5dr2 previous owners', 'Sale Location': 'Mayo'}, {'Model': 'Volkswagen Golf (TSI)', 'Brand': 'Volkswagen', 'Date of Sale': '08/01/2024', 'Sale Price': '€11,444.00', 'Year': '2012', 'Mileage': '26,136', 'Classification': 'Hatchback', 'Transmission': 'Automatic', 'Fuel Type': 'Petrol', 'Description': 'Silver Volkswagen Golf1.4 TSI Match DSG Euro 5 5dr', 'Sale Location': 'Galway'}, {'Model': 'Volkswagen Polo (EVO)', 'Brand': 'Volkswagen', 'Date of Sale': '2024-01-12', 'Sale Price': '€18,183.00', 'Year': '2021', 'Mileage': '2,892', 'Classification': 'Hatchback', 'Transmission': 'Manual', 'Fuel Type': 'Petrol', 'Description': 'Blue Volkswagen PoloMK6 Hatchback 5Dr 1.0 80PS Match EVO', 'Sale Location': 'Kildare'}, {'Model': 'Volkswagen Golf (SE Nav)', 'Brand': 'Volkswagen', 'Date of Sale': '12/01/2024', 'Sale Price': '€17,413.00', 'Year': '2018', 'Mileage': '24,086', 'Classification': 'Hatchback', 'Transmission': 'Manual', 'Fuel Type': 'Petrol', 'Description': 'Blue Volkswagen GolfVolkswagen Golf 1.5 TSI EVO 130 SE Nav 5dr1 previous owner', 'Sale Location': 'Sligo'}, {'Model': 'Volkswagen Scirocco (TDI)', 'Brand': 'Volkswagen', 'Date of Sale': '14/01/2024', 'Sale Price': '€6,372.00', 'Year': '2012', 'Mileage': '132,281 miles', 'Classification': 'Hatchback', 'Transmission': 'Manual', 'Fuel Type': 'Diesel', 'Description': 'Grey Volkswagen Scirocco2.0 TDI BlueMotion Tech R-Line Euro 5 (s/s) ...
# Volkswagen Car Data saved to /Users/jiveshdhakate/Documents/UCD Sem 2/Data Science in Python/car_price_predictor/data/Volkswagen.csv
